# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from PIL import Image
from wordcloud import WordCloud, ImageColorGenerator
from nltk.probability import FreqDist

# %%
df = pd.read_csv('log_token.csv')

# %%
df.head()
# Out:
#    index                       date  \
# 0      0  2020-04-28 00:01:39+00:00
# 1      1  2020-04-28 00:01:40+00:00
# 2      2  2020-04-28 00:01:40+00:00
# 3      3  2020-04-28 00:01:40+00:00
# 4      4  2020-04-28 00:01:40+00:00
#
#                                                 text  \
# 0  RT @jvbessa: Quando voce ve pessoas com 46  48...
# 1  RT @falsinana: jovens furam quarentena e fazem...
# 2    A quarentena esta afetando meu pai  KKKKKKKKKKK
# 3     RT @chandy_teixeira: Por que sera  ne  amigao?
# 4  mano  os patroes da minha mae fizeram ela ir t...
#
#                                           text_token  \
# 0  ['voce', 've', 'pessoas', '46', '48', 'anos', ...
# 1  ['jovens', 'furam', 'quarentena', 'fazem', 'ba...
# 2           ['quarentena', 'afetando', 'pai', 'kkk']
# 3                           ['sera', 'ne', 'amigao']
# 4  ['mano', 'patroes', 'mae', 'fizeram', 'ir', 't...
#
#                                                words
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6545 entries, 0 to 6544
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       6545 non-null   int64
#  1   date        6545 non-null   object
#  2   text        6545 non-null   object
#  3   text_token  6545 non-null   object
#  4   words       6541 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 255.8+ KB

# %%
wordcloud_br = WordCloud(background_color="white", 
                          mode="RGBA", 
                          max_words=60000).generate(str(df['words'].values))

# create coloring from image
plt.figure(figsize=[10,10])
plt.imshow(wordcloud_br, interpolation="bilinear")
plt.axis("off")

# store to file
plt.savefig("quarentena.png", format="png")

plt.show()

# %%
df.count()
# Out:
# index         6545
# date          6545
# text          6545
# text_token    6545
# words         6541
# dtype: int64
